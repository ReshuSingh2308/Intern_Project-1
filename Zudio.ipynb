# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"D:\Internship_Ques\New Project\Zudio_sales_data.csv")

# %%
df.head()
# Out:
#    Store Country          State      City Category Clothing Type  \
# 0  Zudio   India      Karnataka     Jalna    Women       Dresses
# 1  Zudio   India        Gujarat     Patna     Kids        Skirts
# 2  Zudio   India  Uttar Pradesh   Kolkata      Men       Hoodies
# 3  Zudio   India    West Bengal   Kolkata    Women       Dresses
# 4  Zudio   India    West Bengal  Guwahati      Men       Dresses
#
#    Store Number  Postal Code Store Type Store Open Date  ...  \
# 0            30       411084      Owned      2022-06-04  ...
# 1            48       404562      Owned      2020-12-19  ...
# 2            97       437773     Rented      2023-09-04  ...
# 3            93       431725      Owned      2024-04-11  ...
# 4            51       415370      Owned      2022-05-29  ...
#
#    Security Features Order ID  Order Date     Month Customer ID  \
# 0              Alarm    88240  2024-11-06  November      233084
# 1              Alarm    78145  2024-06-17      June      926472
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7899 entries, 0 to 7898
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Store                      7899 non-null   object
#  1   Country                    7899 non-null   object
#  2   State                      7899 non-null   object
#  3   City                       7899 non-null   object
#  4   Category                   7899 non-null   object
#  5   Clothing Type              7899 non-null   object
#  6   Store Number               7899 non-null   int64
#  7   Postal Code                7899 non-null   int64
#  8   Store Type                 7899 non-null   object
#  9   Store Open Date            7899 non-null   object
#  10  Selling Area Size (sq ft)  7899 non-null   int64
#  11  Store Manager              7899 non-null   object
#  12  Manager ID                 7899 non-null   object
# ...

# %%
print(df['Order Date'].dtypes)
# Out:
# object

# %%
df['Order Date']=pd.to_datetime(df['Order Date'])

# %%
print(df['Order Date'].dtypes)
# Out:
# datetime64[ns]

# %%
df['Store Open Date']
# Out:
# 0       2022-06-04
# 1       2020-12-19
# 2       2023-09-04
# 3       2024-04-11
# 4       2022-05-29
#            ...
# 7894    2024-04-24
# 7895    2024-02-03
# 7896    2021-04-11
# 7897    2022-06-17
# 7898    2023-02-08
# Name: Store Open Date, Length: 7899, dtype: object

# %%
df['Order Date']
# Out:
# 0      2024-11-06
# 1      2024-06-17
# 2      2024-08-17
# 3      2024-03-27
# 4      2024-04-08
#           ...
# 7894   2024-09-27
# 7895   2024-03-16
# 7896   2024-12-02
# 7897   2024-07-29
# 7898   2024-04-08
# Name: Order Date, Length: 7899, dtype: datetime64[ns]

# %%
df['Store Open Date']=pd.to_datetime(df['Store Open Date'])

# %%
df['Manager ID']
# Out:
# 0       M77
# 1       M89
# 2       M71
# 3       M40
# 4       M24
#        ...
# 7894    M68
# 7895    M16
# 7896    M21
# 7897    M87
# 7898    M80
# Name: Manager ID, Length: 7899, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7899 entries, 0 to 7898
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Store                      7899 non-null   object
#  1   Country                    7899 non-null   object
#  2   State                      7899 non-null   object
#  3   City                       7899 non-null   object
#  4   Category                   7899 non-null   object
#  5   Clothing Type              7899 non-null   object
#  6   Store Number               7899 non-null   int64
#  7   Postal Code                7899 non-null   int64
#  8   Store Type                 7899 non-null   object
#  9   Store Open Date            7899 non-null   datetime64[ns]
#  10  Selling Area Size (sq ft)  7899 non-null   int64
#  11  Store Manager              7899 non-null   object
#  12  Manager ID                 7899 non-null   object
# ...

# %%
df.describe()
# Out:
#        Store Number    Postal Code             Store Open Date  \
# count   7899.000000    7899.000000                        7899
# mean      50.666034  419982.374984  2022-06-09 20:52:46.578048
# min        1.000000  400006.000000         2020-01-01 00:00:00
# 25%       25.000000  409841.000000         2021-03-18 12:00:00
# 50%       51.000000  419988.000000         2022-06-04 00:00:00
# 75%       76.000000  430258.000000         2023-09-04 00:00:00
# max      100.000000  439985.000000         2024-12-03 00:00:00
# std       29.095274   11695.237817                         NaN
#
#        Selling Area Size (sq ft)  Staff Count      Order ID  \
# count                7899.000000  7899.000000   7899.000000
# mean                 1112.077478    11.504747  54920.719965
# min                   800.000000     3.000000  10008.000000
# 25%                   950.000000     7.000000  33192.000000
# 50%                  1100.000000    12.000000  54873.000000
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Store                           0
# Country                         0
# State                           0
# City                            0
# Category                        0
# Clothing Type                   0
# Store Number                    0
# Postal Code                     0
# Store Type                      0
# Store Open Date                 0
# Selling Area Size (sq ft)       0
# Store Manager                   0
# Manager ID                      0
# Store Address                   0
# Contact Information             0
# Operating Hours                 0
# Staff Count                     0
# Parking Availability            0
# Security Features            2038
# Order ID                        0
# Order Date                      0
# Month                           0
# Customer ID                     0
# Customer Name                   0
# Product ID                      0
# Price                           0
# Quantity                        0
# ...

# %%
df['Security Features']
# Out:
# 0             Alarm
# 1             Alarm
# 2              CCTV
# 3              CCTV
# 4       CCTV, Alarm
#            ...
# 7894    CCTV, Alarm
# 7895          Alarm
# 7896    CCTV, Alarm
# 7897           CCTV
# 7898    CCTV, Alarm
# Name: Security Features, Length: 7899, dtype: object

# %%
df.tail()
# Out:
#       Store Country          State        City Category Clothing Type  \
# 7894  Zudio   India  Uttar Pradesh  Chandigarh     Kids         Jeans
# 7895  Zudio   India  Uttar Pradesh  Aurangabad     Kids       Jackets
# 7896  Zudio   India     Tamil Nadu        Pune     Kids      T-shirts
# 7897  Zudio   India          Delhi     Madurai      Men         Shoes
# 7898  Zudio   India        Gujarat   Bengaluru    Women        Shirts
#
#       Store Number  Postal Code Store Type Store Open Date  ...  \
# 7894            32       431437      Owned      2024-04-24  ...
# 7895            52       424643      Owned      2024-02-03  ...
# 7896            81       412057      Owned      2021-04-11  ...
# 7897            58       405203     Rented      2022-06-17  ...
# 7898            20       429823      Owned      2023-02-08  ...
#
#       Security Features Order ID Order Date      Month Customer ID  \
# 7894        CCTV, Alarm    39056 2024-09-27  September      591993
# ...

# %%
cate_profit=df.groupby('Category')['Sales Profit'].sum()

# %%
cate_profit
# Out:
# Category
# Kids     8441706.8
# Men      8210556.8
# Women    8392869.6
# Name: Sales Profit, dtype: float64

# %%
city_profit=df.groupby('City')['Sales Profit'].sum()

# %%
city_profit
# Out:
# City
# Agra             641221.6
# Ahmedabad        623782.4
# Aurangabad       526490.8
# Bengaluru        629110.0
# Bhopal           658238.8
# Chandigarh       572861.6
# Chennai          591555.2
# Chhattisgarh     629866.0
# Coimbatore       651843.2
# Faridabad        556289.6
# Goa              537166.4
# Guwahati         525460.8
# Hyderabad        657118.8
# Indore           636326.4
# Jaipur           606880.8
# Jalna            687870.4
# Jammu            665838.4
# Kanpur           589374.8
# Kochi            562828.8
# Kolhapur         620624.4
# Kolkata          658384.4
# Lucknow          619756.4
# Madurai          629542.8
# Meerut           563091.2
# Mumbai           465306.0
# Mysuru           681431.6
# Nagpur           535366.4
# Nashik           532747.6
# New Delhi        626567.6
# Noida            605664.4
# Patna            596005.6
# Pondicherry      545814.0
# Pune             608094.0
# Rajkot           633832.0
# Ranchi           559431.6
# ...

# %%
# Correlation

df[['Quantity','Sales Profit']].corr()
# Out:
#               Quantity  Sales Profit
# Quantity      1.000000      0.739751
# Sales Profit  0.739751      1.000000

# %%
correlation = df['Quantity'].corr(df['Sales Profit'])

# %%
correlation
# Out:
# 0.7397510898199978

# %%
df.to_csv('data.csv', index=False)  # Save to CSV
